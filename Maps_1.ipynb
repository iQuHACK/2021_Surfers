# %%
# !pip install geopy
from geopy import distance
import numpy as np

# %%
locations = [["Androscoggin", (44.1912, 70.1707)],
            ["Aroostook", (46.8199, 68.4766)],
            ["Cumberland", (43.8133, 70.3871)],
            ["Franklin", (45.0386, 70.398)],
            ["Hancock", (44.577, 68.3567)],
            ["Kennebec", (44.4499, 69.7038)],
            ["Knox", (43.997, 68.9243)],
            ["Lincoln", (44.1083, 69.511)],
            ["Oxford", (44.4907, 70.7841)],
            ["Penobscot", (45.3231, 68.5807)],
            ["Piscataquis", (45.705, 69.3375)],
            ["Sagadahoc", (43.8171, 69.7826)],
            ["Somerset", (45.5913, 69.9999)],
            ["Waldo", (44.5107, 69.2078)],
            ["Washington", (44.9849, 67.6777)],
            ["York", (43.4133, 70.6703)]]

# %%
# Test formula
# a = 3
# b = 3
# print("Dist from " + locations[a][0] + " to " + locations[b][0] + ": " + str(distance.distance(locations[a][1], locations[b][1]).km))

# %%
distances = []

for i in range(len(locations)):
    for j in range(len(locations)):
        distances.append((distance.distance(locations[i][1], locations[j][1]).km))

print(distances)
# Out:
# [0.0, 320.73564847713646, 45.43489021303682, 95.87929473277993, 150.7713288946005, 47.04901133257844, 102.11565562403139, 53.5764083100175, 59.16329507435939, 177.9572265872226, 180.62075023469384, 51.92908014167199, 156.1764282032889, 84.58444611633239, 216.71431727843884, 95.32369355119434, 320.73564847713646, 0.0, 366.1611489019258, 247.79265403708987, 249.46281938090132, 280.2427578083941, 315.6863748960009, 312.030408883602, 315.18927650886195, 166.56814178226, 140.58041049756633, 349.06823858580634, 180.18952259559416, 262.9013577235761, 213.16942422149268, 416.0391881257313, 45.43489021303682, 366.1611489019258, 0.0, 136.1587908999571, 183.15219721905612, 89.40749334600883, 119.27010975343471, 77.57890319931519, 81.69558507451968, 220.75625199461044, 226.04357028377078, 48.63660461113174, 199.95007773272908, 122.07562152620027, 252.04974937959213, 49.97715237049302, 95.87929473277993, 247.79265403708987, 136.1587908999571, 0.0, 169.43301501047551, 85.45363631276344, 164.691178
# ...

# %%
distance_matrix = np.array(distances)
shape = (len(locations), len(locations))
distance_matrix.reshape(shape)
# Out:
# array([[  0.        , 320.73564848,  45.43489021,  95.87929473,
#         150.77132889,  47.04901133, 102.11565562,  53.57640831,
#          59.16329507, 177.95722659, 180.62075023,  51.92908014,
#         156.1764282 ,  84.58444612, 216.71431728,  95.32369355],
#        [320.73564848,   0.        , 366.1611489 , 247.79265404,
#         249.46281938, 280.24275781, 315.6863749 , 312.03040888,
#         315.18927651, 166.56814178, 140.5804105 , 349.06823859,
#         180.1895226 , 262.90135772, 213.16942422, 416.03918813],
#        [ 45.43489021, 366.1611489 ,   0.        , 136.1587909 ,
#         183.15219722,  89.40749335, 119.27010975,  77.5789032 ,
#          81.69558507, 220.75625199, 226.04357028,  48.63660461,
#         199.95007773, 122.07562153, 252.04974938,  49.97715237],
#        [ 95.87929473, 247.79265404, 136.1587909 ,   0.        ,
#         169.43301501,  85.45363631, 164.69117817, 125.10133351,
#          68.12852102, 146.29094431, 111.29373225, 144.30723538,
# ...
